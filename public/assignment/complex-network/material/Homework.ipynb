# %% [markdown]
# # Complex Networks Homework - Your Name - QMUL Student ID

# %% [markdown]
# ## `TASK 0: edit the header`
#
# Edit the cell above to change "Your Name" to your name and "QMUL Student ID" to your QMUL student ID.
#
# Tip: to edit a markdown cell, double click it.

# %% [markdown]
# ### `Instructions`
#
# Please read these instructions carefully. It is your responsibility to read and understand them all. If you have any questions, please email Matteo.
#
# #### What you will do
#
# You will **build, analyse** and **discuss** a network representation of the Beijing Metro system.
#
# For each tasks, you will need to **write code and explain your results using words and visuals.** Code is not sufficient: you must show your reasoning.
#
# In all tasks, your answers **must be your own work and your own writing**. Do not use services like DeepSeek or ChatGPT to write answers for you.
#
# #### Evaluation
#
# The assignment is worth 35% of your grade.
#
# Your submission will be evaluated based on:
#
# 1. The soundness of the selected methods.
# 2. The correctness and clarity of the computational analysis.
# 3. The quality of your explanations.
#
# The assignment is graded out of 70 points total. The weight of each task in points is indicated like this:
#
# > `Task 1: Data description` (5 points)
#
# #### Submission
#
# The deadline is 30th April 2026. You thus have about one month to complete the assignment.
#
# When you have finished editing your `.ipynb` file, upload it to the QMplus submission point.
# - NB: your code *must* work using the original data file.
#
# Remember to:
# - [ ] Include your name and QMUL student ID in the header above;
# - [ ] Double check that your notebook runs smoothly from a **fresh kernel**;
# 	- Tip: use the menu option `Kernel > Restart Kernel and Run All Cells...`
# - [ ] Sign the declaration at the bottom of the notebook by ticking the checkboxes.

# %% [markdown]
# ## `Task 1: Data description` (5 marks)

# %% [markdown]
# You are provided with a data set of metro lines.
#
# 1. Describe the data using at most 150 words. What does the data contain? Data Limitations: What other information could be helpful for a user that the data does not provide?

# %% [markdown]
# Answer 1. Add cells if necessary

# %% [markdown]
# ## `Task 2: Network construction` (10 marks)

# %% [markdown]
# 2.1. Construct the network where each node represents a station and two stations are connected by an edge if they are consecutive stops along the same metro line.

# %%
# Answer 2.1. Add cells if necessary

# %% [markdown]
# 2.2. Visualise the network using the (approximate) coordinates as layout. How does the network reflect Beijing's layout? Compare the network plot with a map (e.g., from Baidu). Does the network topology reflect the road structure of Beijing? Are there areas of the city that appear underserved?

# %%
# Answer 2.2. Add cells if necessary

# %% [markdown]
# 2.3. Explain your network design choices in at most 150 words (is the network directed or undirected? which attributes and weights did you assign to the nodes and edges and why?)

# %% [markdown]
# Answer 2.3. Add cells if necessary

# %% [markdown]
# ## `Task 3: Analysis` (50 marks)

# %% [markdown]
# Address the following questions and comment upon them. Where appropriate, illustrate the measures with visuals (at most 4 per question).

# %% [markdown]
# 3.1. *Centrality analysis*: Study the degree, closeness, and betweenness centrality of the network. In what cases does it make sense to use "distance" as a weight? Compute the degree distributions of the network. What conclusion can you derive? Comment in at most 250 words. (10 marks)

# %%
# Answer 3.1. Add cells if necessary

# %% [markdown]
# 3.2. *Robustness*: How robust is the network under random station failure? How robust is the network under targeted attacks to stations with large degree or betweenness? Address these questions by studying the size of the largest connected component and the average path length. Based on your robustness analysis, which stations or areas of the city are most vulnerable, and what would you recommend? Comment in at most 500 words. (20 marks)

# %%
# Answer 3.2. Add cells if necessary

# %% [markdown]
# 3.3. *Comparison with Network models*: How do the network centrality and robustness compare to a configuration model preserving the degree sequence and attacked in the same ways? Consider 10 random realisations of the network and consider the average. Ensure the results are reproducible. Comment in at most 500 words. (20 marks)

# %%
# Answer 3.3. Add cells if necessary

# %% [markdown]
# ## `Task 4: Reflection and Feedback` (5 marks)

# %% [markdown]
# 4. What did you learn from this task? What aspect of the homework would you like to receive more in-depth feedback on?

# %% [markdown]
# Answer 4. Add cells if necessary

# %% [markdown]
# ## `Task 5: submission checklists`

# %% [markdown]
# To tick the boxes below, double click on the segment, and change the empty tickboxes to checked ones: `[ ]` to `[x]`

# %% [markdown]
# <div style="padding: 10px; border: 2px solid blue;">
#
# **Academic honesty declaration**
# * [ ] I declare that I have completed this assignment on my own.
# * [ ] I declare that I have not used AI tools to complete this assignment.
#
# Your Name
# </div>

# %% [markdown]
# <div style="padding: 10px; border: 2px solid blue;">
#
# Before I uploaded my submission to QMplus, I checked that:
#
# * [ ] My name and QMUL ID have been added to the top of the notebook.
# * [ ] My name is in the **academic honesty declaration** above, and I have ticked the box to sign it.
# * [ ] When I run `"Restart kernel and run all cells"`, all of the code runs without error.
# * [ ] I have saved the notebook **after** running all cells.
# * [ ] I have not edited the data; all the steps to clean and modify the data take place within this notebook.
#
# </div>

# %% [markdown]
# Once you have affirmed all of the above, you may upload the `.ipynb` file directly to QMplus.
#
# The deadline to submit your assignment is **Thursday the 30th of April, 2026 (2026-04-30) at 17:00 in China Standard Time.**.
